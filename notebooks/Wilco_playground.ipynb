# %% [markdown]
# ### Imports

# %%
import sys; sys.path.append('..')
from brian2 import *
import numpy as np
from utils.simulate import RecurrentNeuralNetwork
from tests.simulate_test import RecurrentNeuralNetworkTestCase

import matplotlib.pyplot as plt

# %% [markdown]
# ### Functions

# %% [markdown]
# ### Testing area

# %%
test_cases = RecurrentNeuralNetworkTestCase

# %%
RecurrentNeuralNetworkTestCase.test_sim_plot_state(test_cases)
# Out:
# Starting simulation at t=0. s for a duration of 1.2 s
# 1.2 s (100%) simulated in 3s

# %%
RecurrentNeuralNetworkTestCase.test_sim_plot_connectivity(test_cases)
# Out:
# Starting simulation at t=0. s for a duration of 10. ms
# 10. ms (100%) simulated in < 1s
# WARNING    c:\Users\wilco\OneDrive\School_delft\Year 5 (Master)\Quarter 1\Modeling dynamical systems\criticality-and-cascades\notebooks\..\utils\simulate.py:253: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
#  [py.warnings]
